# %% [markdown]
# # The Littlest JupyterHub (TLJH) の解析環境構築

# %% [markdown]
# ## Mdx仮想マシンの準備

# %% [markdown]
# クラウドサービスとしてmdxを使用する場合は事前に仮想マシンをデプロイする必要があります。
# 以下のセルを実行し、リンク先で仮想マシンを準備してください。
# mdx以外のクラウドサービス(AWS,Azure,GCP, etc.)を使用する場合は不要です。

# %%
# Mdx仮想マシンの準備
from IPython.core.display import HTML
from library.utils.html import button

display(HTML(
    button.create_button(
        url='../CoursewareHub/notebooks/941-mdx仮想マシンの準備.ipynb',
        msg='Mdx仮想マシンの準備',
        target='_blank',
    )
))

# %% [markdown]
# ## The Littlest JupyterHubの環境構築

# %% [markdown]
# The Littlest JupyterHub環境を構築します。
# 以下のセルを実行し、リンク先で環境構築します。

# %%
# JupyterHub環境構築
from IPython.core.display import HTML
from library.utils.html import button

display(HTML(
    button.create_button(
        url='001-JupyterHub環境構築.ipynb',
        msg='JupyterHub環境構築',
        target='_blank',
    )
))
